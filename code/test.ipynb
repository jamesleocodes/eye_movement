# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
path = ['../../smooth_pursuit/Eye_Tracker_Data/HC_1/',
        '../../smooth_pursuit/Eye_Tracker_Data/PD/',
        '../../smooth_pursuit/result/dataset/Stimulus/',
        '../../smooth_pursuit/Eye_Tracker_Data/PD/',]

# %%
data = pd.read_csv('four_deg.csv')
sns.lineplot(x='x1_PD002_left',y='y1_PD002_left',data=data)

data_sti= pd.read_csv(path[2]+'4_deg_per_sec_sti.csv')
sns.lineplot(x='x', y='y', data=data_sti)
# Out:
# <AxesSubplot:xlabel='x1_PD002_left', ylabel='y1_PD002_left'>

# %%
data = pd.read_csv(path[0]+'four_deg.csv')
for column in data.columns:
    data[column] = data[column].interpolate().ffill().bfill()
#data['x2_PD008_right'] = data['x2_PD008_right'].interpolate().ffill().bfill()
data.isnull().sum().sort_values(ascending = False)
# Out:
# x1_PD009_right    0
# y1_PD009_right    0
# x1_PD003_left     0
# y1_PD003_left     0
# x2_PD003_left     0
# y2_PD003_left     0
# x1_PD001_right    0
# y1_PD001_right    0
# x2_PD001_right    0
# y2_PD001_right    0
# x1_PD006_left     0
# y1_PD006_left     0
# x2_PD006_left     0
# y2_PD006_left     0
# x1_PD010_left     0
# y1_PD010_left     0
# x2_PD010_left     0
# y2_PD010_left     0
# x1_PD007_right    0
# y1_PD007_right    0
# x2_PD007_right    0
# y2_PD007_right    0
# x1_PD005_right    0
# y1_PD005_right    0
# x2_PD005_right    0
# y2_PD011_right    0
# x2_PD011_right    0
# y1_PD011_right    0
# x1_PD013_right    0
# x2_PD009_right    0
# y2_PD009_right    0
# x1_PD012_left     0
# y1_PD012_left     0
# x2_PD012_left     0
# y2_PD012_left     0
# x1_PD004_left     0
# y1_PD004_left     0
# x2_PD004_left     0
# y2_PD004_left     0
# y1_PD013_right    0
# x1_PD011_right    0
# x2_PD013_right    0
# y2_PD013_right    0
# x1_PD002_left     0
# y1_PD002_left     0
# ...

# %%
#data = pd.read_csv(path[0]+'two_deg.csv')
sns.lineplot(x='x2_PD008_right',y='y2_PD008_right',data=data)

data_sti= pd.read_csv(path[2]+'4_deg_per_sec_sti.csv')
sns.lineplot(x='x', y='y', data=data_sti)
# Out:
# <AxesSubplot:xlabel='x2_PD008_right', ylabel='y2_PD008_right'>

# %%
data = pd.read_csv(path[1]+'one_deg.csv')
sns.lineplot(x='x2_PDPW102_right',y='y2_PDPW102_right',data=data)

data_sti= pd.read_csv(path[2]+'1_deg_per_sec_sti.csv')
sns.lineplot(x='x', y='y', data=data_sti)
# Out:
# <AxesSubplot:xlabel='x2_PDPW102_right', ylabel='y2_PDPW102_right'>

# %%
data = pd.read_csv(path[3]+'one_deg.csv')
sns.lineplot(x='x2_PDPW102_right',y='y2_PDPW102_right',data=data)

data_sti= pd.read_csv(path[2]+'1_deg_per_sec_sti.csv')
sns.lineplot(x='x', y='y', data=data_sti)
# Out:
# <AxesSubplot:xlabel='x2_PDPW102_right', ylabel='y2_PDPW102_right'>

# %%
y
# Out:
#       x1_PDPW102_right  y1_PDPW102_right  x2_PDPW102_right  y2_PDPW102_right  \
# 0               0.0033           -1.7339            0.0033           -1.0282
# 1               0.0067           -1.6129            0.0067           -1.1290
# 2               0.0100           -1.6734            0.0100           -1.0282
# 3               0.0133           -1.5726            0.0133           -1.2097
# 4               0.0167           -1.5524            0.0167           -1.1895
# ...                ...               ...               ...               ...
# 3297           10.9933            4.8790           10.9933            6.2298
# 3298           10.9967            4.8589           10.9967            6.5524
# 3299           11.0000            4.8185           11.0000            6.4516
# 3300           11.0033            5.1008           11.0033            6.4718
# 3301           11.0067            5.4234           11.0067            6.3911
#
# ...

# %%
y = pd.read_csv(path[0]+'one_deg.csv')
sns.lineplot(x='x1_PD009_right',y='y1_PD009_right',data=y)

x= pd.read_csv(path[2]+'1_deg_per_sec_sti.csv')
sns.lineplot(x='x', y='y', data=x)
# Out:
# <AxesSubplot:xlabel='x1_PD009_right', ylabel='y1_PD009_right'>

# %%
#HC = pd.read_csv(path[0]+'one_deg.csv')
HC = pd.read_csv(path[0]+'one_deg.csv')
Sti = pd.read_csv(path[2]+'8_deg_per_sec_sti.csv')

# %%
HC.plot(x='x1_PD013',y='y1_PD013')
plt.legend(loc='lower left')

# %%
HC.columns
# Out:
# Index(['x1_PD011', 'y1_PD011', 'x2_PD011', 'y2_PD011', 'x1_PD010', 'y1_PD010',
#        'x2_PD010', 'y2_PD010', 'x1_PD003', 'y1_PD003', 'x2_PD003', 'y2_PD003',
#        'x1_PD004', 'y1_PD004', 'x2_PD004', 'y2_PD004', 'x1_PD005', 'y1_PD005',
#        'x2_PD005', 'y2_PD005', 'x1_PD002', 'y1_PD002', 'x2_PD002', 'y2_PD002',
#        'x1_PD012', 'y1_PD012', 'x2_PD012', 'y2_PD012', 'x1_PD013', 'y1_PD013',
#        'x2_PD013', 'y2_PD013', 'x1_PD007', 'y1_PD007', 'x2_PD007', 'y2_PD007',
#        'x1_PD009', 'y1_PD009', 'x2_PD009', 'y2_PD009', 'x1_PD008', 'y1_PD008',
#        'x2_PD008', 'y2_PD008', 'x1_PD001', 'y1_PD001', 'x2_PD001', 'y2_PD001',
#        'x1_PD006', 'y1_PD006', 'x2_PD006', 'y2_PD006'],
#       dtype='object')

# %%
org_path = '../../smooth_pursuit/data/subjects/HC/'

# %%
org_pd = pd.read_excel(org_path+"PD001/1_dps.xlsx")
# Out:
# /Users/zaw/miniforge3/envs/ds/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
option = ['URLStart','URLEnd']
t = org_pd[org_pd['StudioEvent'].isin(option)].index # Caculating start and end of stimuli
data_eye_pd_first = org_pd[t[0]+902:t[0]+27904]

# %%
plt.plot(data_eye_pd_first['GazePointRightX (ADCSpx)'])

# %%
data_eye_pd_first['GazePointRightX (ADCSpx)'].isna().sum()
# Out:
# 824

# %% [markdown]
# ### Blinks

# %%
import pandas as pd
import numpy as np

# %%
a = np.array([3,1, np.nan, np.nan, np.nan, 3, np.nan, 4,np.nan,np.nan, 5, np.nan,np.nan,np.nan,np.nan, 6, 7,np.nan,np.nan,np.nan])
a = pd.Series(a)
def blink_nan(series,i):
    df = pd.DataFrame(series)
    df['new'] = ((df[i].notnull() != df[i].shift().notnull()).cumsum())
    df['ones'] =1
    mask_zeros = (df.groupby('new')['ones'].transform('count') == 3) | df[i].notnull()
    blink_series = series.fillna(0).where(mask_zeros)
    interpolate_series = pd.Series(blink_series).interpolate()
    return interpolate_series

blink_nan(a,0)
# Out:
# 0     3.000000
# 1     1.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# 5     3.000000
# 6     3.500000
# 7     4.000000
# 8     4.333333
# 9     4.666667
# 10    5.000000
# 11    5.200000
# 12    5.400000
# 13    5.600000
# 14    5.800000
# 15    6.000000
# 16    7.000000
# 17    0.000000
# 18    0.000000
# 19    0.000000
# dtype: float64

# %%
df_1 = pd.DataFrame([3,4,4,5],columns=['A'])

# %%
df_2 = pd.DataFrame([1,10,4,4,0,6,7,9,24],columns=['B'])

# %%
index_subj = df_2['B'].isin(df_1['A']).astype(int)
index_subj
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# 5    0
# 6    0
# 7    0
# 8    0
# Name: B, dtype: int64

# %%
df_3 = pd.DataFrame(index_subj)

# %%
df_3[df_3['B'] == 1].index
# Out:
# Int64Index([2, 3], dtype='int64')

# %%
import sklearn
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt

# %%
bos_hou = load_boston()
column_name = bos_hou.feature_names
df_boston = pd.DataFrame(bos_hou.data)
df_boston.columns = column_name
df_boston.head()
# Out:
# /Users/zaw/miniforge3/envs/ds/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
import seaborn as  sns
sns.boxplot(df_boston['DIS'])
# Out:
# /Users/zaw/miniforge3/envs/ds/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DIS'>
